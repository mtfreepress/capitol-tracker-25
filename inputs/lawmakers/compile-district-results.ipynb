# %%
import json
from math import ceil
import pandas as pd

# %%
hds = ["HD 1","HD 2","HD 3","HD 4","HD 5","HD 6","HD 7","HD 8","HD 9","HD 10","HD 11","HD 12","HD 13","HD 14","HD 15","HD 16","HD 17","HD 18","HD 19","HD 20","HD 21","HD 22","HD 23","HD 24","HD 25","HD 26","HD 27","HD 28","HD 29","HD 30","HD 31","HD 32","HD 33","HD 34","HD 35","HD 36","HD 37","HD 38","HD 39","HD 40","HD 41","HD 42","HD 43","HD 44","HD 45","HD 46","HD 47","HD 48","HD 49","HD 50","HD 51","HD 52","HD 53","HD 54","HD 55","HD 56","HD 57","HD 58","HD 59","HD 60","HD 61","HD 62","HD 63","HD 64","HD 65","HD 66","HD 67","HD 68","HD 69","HD 70","HD 71","HD 72","HD 73","HD 74","HD 75","HD 76","HD 77","HD 78","HD 79","HD 80","HD 81","HD 82","HD 83","HD 84","HD 85","HD 86","HD 87","HD 88","HD 89","HD 90","HD 91","HD 92","HD 93","HD 94","HD 95","HD 96","HD 97","HD 98","HD 99","HD 100"]
sds = ["SD 1","SD 2","SD 3","SD 4","SD 5","SD 6","SD 7","SD 8","SD 9","SD 10","SD 11","SD 12","SD 13","SD 14","SD 15","SD 16","SD 17","SD 18","SD 19","SD 20","SD 21","SD 22","SD 23","SD 24","SD 25","SD 26","SD 27","SD 28","SD 29","SD 30","SD 31","SD 32","SD 33","SD 34","SD 35","SD 36","SD 37","SD 38","SD 39","SD 40","SD 41","SD 42","SD 43","SD 44","SD 45","SD 46","SD 47","SD 48","SD 49","SD 50"]
locales = {"HD 1":"Libby, Troy","HD 2":"Eureka","HD 3":"Columbia Falls, West Glacier, Hungry Horse","HD 4":"Northeast of Kalispell","HD 5":"Whitefish","HD 6":"Northwest of Kalispell","HD 7":"Central Kalispell","HD 8":"West and south Kalispell","HD 9":"Northeast Kalispell","HD 10":"Bigfork, Swan Lake","HD 11":"South of Kalispell, Somers","HD 12":"Polson","HD 13":"Thompson Falls, Heron, Marion","HD 14":"St. Regis, Superior, Hot Springs, Dixon, Alberton","HD 15":"Browning, Heart Butte","HD 16":"Browning, East Glacier, Cut Bank","HD 17":"Fairfield, Choteau, Augusta, Valier, Brady","HD 18":"Conrad, Shelby, Cut Bank","HD 19":"Ulm, Cascade, Simms, Belt","HD 20":"South of Great Falls","HD 21":"North side of Great Falls","HD 22":"Northwest Great Falls","HD 23":"South side of Great Falls","HD 24":"Central Great Falls","HD 25":"Central Great Falls","HD 26":"Great Falls and Malmstrom AFB","HD 27":"Fort Benton, Geraldine, Chester, Big Sandy","HD 28":"Havre","HD 29":"Lewistown, Winifred, Roy, Winnett","HD 30":"Martinsdale, White Sulphur Springs, Geyser, Lavina","HD 31":"Poplar, Fort Peck, Wolf Point","HD 32":"Box Elder, Chinook, Hays","HD 33":"Malta, Glasgow, Chinook","HD 34":"Culbertson, Opheim, Plentywood","HD 35":"Sidney, Lambert, Savage","HD 36":"Glendive, Wibaux","HD 37":"Circle, Jordan, Terry, Baker, Ekalaka, Broadus","HD 38":"Miles City","HD 39":"Forsyth, Worden, Hysham, Colstrip","HD 40":"Roundup, Meltsone, Broadview, Shepherd","HD 41":"Lame Deer, Busby, Colstrip, Wyola","HD 42":"Crow Agency, Hardin","HD 43":"Northeast Billings","HD 44":"Northeast Billings","HD 45":"North of Billings","HD 46":"Northwest Billings","HD 47":"Central Billings","HD 48":"Central Billings","HD 49":"Central Billings","HD 50":"Central Billings","HD 51":"South of Billings","HD 52":"Central Billings","HD 53":"West of Billings","HD 54":"West Billings","HD 55":"Laurel, South of Billings","HD 56":"Southeast of Billings","HD 57":"Columbus, Absarokee, Reed Point, Rapelje, Park City","HD 58":"Joliet, Red Lodge, Belfry","HD 59":"Pray, Gardiner, Wilsall, Big Timber","HD 60":"Livingston","HD 61":"East Bozeman","HD 62":"South Bozeman","HD 63":"Southwest Bozeman","HD 64":"Bozeman, Gallatin Gateway, Big Sky, West Yellowstone","HD 65":"Northwest Bozeman","HD 66":"Central Bozeman","HD 67":"Belgrade","HD 68":"Belgrade","HD 69":"Manhattan, Three Forks","HD 70":"Townsend","HD 71":"Twin Bridges, Sheridan, Virginia City, Ennis","HD 72":"Dillon, Lima","HD 73":"Southwest Butte","HD 74":"Northwest Butte","HD 75":"Clancy, Boulder, Whitehall","HD 76":"Southeast Butte","HD 77":"Anaconda, Philipsburg, Drummund","HD 78":"Deer Lodge, Warm Springs","HD 79":"West Helena","HD 80":"Elliston, Lincoln","HD 81":"Central Helena, Helena Valley","HD 82":"Central Helena, Helena Valley","HD 83":"Central Helena, Helena Valley","HD 84":"Helena, East Helena","HD 85":"Hamilton, Darby","HD 86":"Hamilton","HD 87":"Pinesdale, Victor, Corvallis","HD 88":"Florence, Stevensville","HD 89":"Missoula","HD 90":"South Missoula","HD 91":"Northeast Missoula","HD 92":"East Missoula, Clinton, Seeley Lake, Condon","HD 93":"Ronan, Charlo, Arlee","HD 94":"Missoula, Frenchtown","HD 95":"North Missoula","HD 96":"Northwest Missoula","HD 97":"West of Missoula","HD 98":"West Missoula","HD 99":"Southwest Missoula","HD 100":"Central Missoula","SD 1":"Troy, Libby, Eureka","SD 2":"Columbia Falls, West Glacier, Hungry Horse","SD 3":"Whitefish","SD 4":"Kalispell","SD 5":"Bigfork, Swan Lake","SD 6":"Polson, Somers","SD 7":"Noxon, St Regis, Alberton, Marion, Dixon","SD 8":"Browning, East Glacier, Heart Butte","SD 9":"Ethridge, Augusta, Choteau, Shelby, Cut Bank ","SD 10":"South of Great Falls, Simms, Cascade, Belt","SD 11":"Northwest Great Falls","SD 12":"South Great Falls","SD 13":"Northeast Great Falls","SD 14":"Chester, Havre, Fort Benton","SD 15":"Buffalo, Lewistown, White Sulphur Springs, Winnett","SD 16":"Hays, Box Elder, Fort Peck, Wolf Point, Poplar","SD 17":"Malta, Glasgow, Plentywood","SD 18":"Wibaux, Glendive, Sidney","SD 19":"Miles City, Jordan, Terry, Baker, Ekalaka","SD 20":"Colstrip, Custer, Forsyth, Worden","SD 21":"Busby, Hardin, Crow Agency, Lame Deer, Ashland","SD 22":"Northeast Billings","SD 23":"Northwest Billings","SD 24":"Central Billings","SD 25":"Central Billings","SD 26":"South Billings","SD 27":"West Billings ","SD 28":"Laurel, South of Billings","SD 29":"Park City, Reed Point, Red Lodge","SD 30":"Big Timber, Livingston, Gardiner, Wilsall","SD 31":"East Bozeman","SD 32":"Southwest Bozeman, Big Sky, West Yellowstone","SD 33":"Bozeman","SD 34":"Belgrade","SD 35":"Manhattan, Three Forks, Townsend","SD 36":"Dillon, Twin Bridges, Ennis","SD 37":"Butte","SD 38":"Butte, Boulder, Clancy","SD 39":"Philipsburg, Anaconda, Deer Lodge, Warm Springs","SD 40":"Helena, Lincoln","SD 41":"Helena, Helena Valley","SD 42":"Helena, East Helena","SD 43":"Hamilton, Darby","SD 44":"Pinesdale, Victor, Stevensville, Florence","SD 45":"Missoula","SD 46":"Missoula, East Missoula, Seeley Lake","SD 47":"Ronan, Charlo, Arlee, Frenchtown","SD 48":"Northwest Missoula","SD 49":"West Missoula","SD 50":"Central Missoula"}

# %%
# Functions
def parse_sheet(xl, sheet):
    raw = xl.parse(sheet, skiprows=6)
    columns = list(raw.columns)
    race_name = columns[0]
    candidate_cols =  columns[2:]
    candidates = list(map(lambda n: n.split('\n')[0], candidate_cols))
    parties = list(map(lambda n: n.split('\n')[1], candidate_cols))
    df = raw.drop(columns=race_name)
    df = df[df['County'] == 'TOTALS'].melt(id_vars='County', value_name='votes')
    df['name'] = df['variable'].apply(lambda s: s.split('\n')[0])
    df['party'] =  df['variable'].apply(lambda s: s.split('\n')[1])
    df['party'] = df['party'].replace({
        'Democrat': 'D',
        'Republican': 'R',
        'Libertarian': 'L',
    })
    df['race'] = race_name
    df['race'] = df['race'].replace({
        'STATE SENATOR DISTRICT': 'SD',
        'STATE REPRESENTATIVE DISTRICT': 'HD',
    }, regex=True)
    return df[['race','name','party','votes']]
  

def parse_sheets(file):
    xl = pd.ExcelFile(file)
    sheets = xl.sheet_names
    df = pd.DataFrame()
    for sheet in sheets:
        dfi = parse_sheet(xl, sheet)
        df = pd.concat([df, dfi])

    return df

def hd_to_sd(key):
    # Return key for Senate District encompassing given House District
    hd_num = int(key.replace('HD ',''))
    sd_num = ceil(hd_num / 2)
    return f'SD {sd_num}'

def sd_to_hds(key):
    # Return array of two keys for House Districts within given Senate District
    sd_num = int(key.replace('SD ',''))
    return [f'HD {sd_num*2-1}', f'HD {sd_num*2}']


gov_20_general = pd.read_csv('raw/gov-votes-by-hd-2020-gen.csv')
gov_20_general = gov_20_general.melt(id_vars='hd', var_name='name', value_name='votes')
gov_20_general['party'] = gov_20_general['name'].replace({
    'Bishop': 'L',
    'Cooney': 'D',
    'Gianforte': 'R',
})
gov_20_general['sd'] = gov_20_general['hd'].map(hd_to_sd)

leg_20_primary = parse_sheets('raw/legislative-results-2020-primary.xlsx')
leg_20_general = parse_sheets('raw/legislative-results-2020-general.xlsx')
leg_22_primary = parse_sheets('raw/legislative-results-2022-primary.xlsx')
leg_22_general = parse_sheets('raw/legislative-results-2022-general.xlsx')

# sds_in_cycle_2022 = [f'SD {i}' for i in [2,3,6,7,10,16,17,18,21,23,25,26,28,31,35,36,37,38,40,44]]
sds_in_cycle_2022 = [f'SD {i}' for i in [1,4,5,8,9,11,12,13,14,15,19,20,22,24,27,29,30,32,33,34,39,41,42,43,48,49,50]]

# %%
def collect_data_house(hd):
    gov_gen = gov_20_general[gov_20_general['hd'] == hd].sort_values('votes', ascending=False)
    leg_gen = leg_22_general[leg_22_general['race'] == hd].sort_values('votes', ascending=False)
    leg_pri = leg_22_primary[leg_22_primary['race'] == hd].sort_values('votes', ascending=False)
    return {
        'key': hd,
        'last_election': '2022',
        'pri_elex': {
            'leg': leg_pri[['name','party','votes']].to_dict(orient='records')
        },
        'gen_elex': {
            'gov': gov_gen[['name','party','votes']].to_dict(orient='records'),
            'leg': leg_gen[['name','party','votes']].to_dict(orient='records')
        },   
        'locale': locales[hd],
    }

def collect_data_senate(sd):
    gov_gen = gov_20_general[gov_20_general['sd'] == sd]\
        .groupby(['name','party']).agg(votes=('votes','sum')).reset_index()\
        .sort_values('votes', ascending=False)

    last_election = '2022' if sd in sds_in_cycle_2022 else '2020'
    if (last_election == '2022'):
        leg_pri = leg_22_primary[leg_22_primary['race'] == sd].sort_values('votes', ascending=False)
    else:
        leg_pri = leg_20_primary[leg_20_primary['race'] == sd].sort_values('votes', ascending=False)
    
    if (last_election == '2022'):
        leg_gen = leg_22_general[leg_22_general['race'] == sd].sort_values('votes', ascending=False)
    else:
        leg_gen = leg_20_general[leg_20_general['race'] == sd].sort_values('votes', ascending=False)
    
    return {
        'key': sd,
        'last_election': last_election,
        'pri_elex': {
            'leg': leg_pri[['name','party','votes']].to_dict(orient='records')
        },
        'gen_elex': {
            'gov': gov_gen[['name','party','votes']].to_dict(orient='records'),
            'leg': leg_gen[['name','party','votes']].to_dict(orient='records')
        },
        'locale': locales[sd],
    }

house_data = [collect_data_house(hd) for hd in hds]
senate_data = [collect_data_senate(sd) for sd in sds]

combined = house_data + senate_data

# %%
with open('districts-2023.json', 'w') as f:
    stringed = json.dumps(combined, indent=4)
    f.write(stringed)
